# %% [markdown]
# # WEB SCRAPING

# %% [markdown]
# # importing libraries

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # scrabing a website

# %%
url="https://www.flipkart.com/pens-stationery/calculators/pr?sid=dgv%2Cqtq"

# %%
url
# Out:
# 'https://www.flipkart.com/pens-stationery/calculators/pr?sid=dgv%2Cqtq'

# %% [markdown]
# # website response

# %%
res=requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %% [markdown]
# # parsing

# %%
soup=BeautifulSoup(res.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # to select a particular portion

# %%
products=soup.select('.s1Q9rs')

# %%
products
# Out:
# [<a class="s1Q9rs" href="/casio-mj-12d-bk-desktop-basic-calculator/p/itmc4e095765eeac?pid=CALEGGVZTFHPSACB&amp;lid=LSTCALEGGVZTFHPSACBWFYZWW&amp;marketplace=FLIPKART&amp;store=dgv%2Fqtq&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=f8ce7ebe-0ca0-4557-8bcf-082c86f97b35.CALEGGVZTFHPSACB.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=73rhgz7brk0000001663149166561" rel="noopener noreferrer" target="_blank" title="CASIO MJ-12D-BK Desktop Basic  Calculator">CASIO MJ-12D-BK Desktop Basic  Calculator</a>,
# ...

# %%
products_title=[]

# %%
for item in products:
    products_title.append(item.text)

# %%
products_title
# Out:
# ['CASIO MJ-12D-BK Desktop Basic  Calculator',
#  'CASIO Classwiz FX-991EX Scientific  Calculator',
#  'CASIO FX-82MS Scientific Scientific  Calculator',
#  'CASIO FX-991ES Plus-2nd Edition Scientific Scientific  ...',
#  'OREVA OR 240 MS OR 240 MS Scientific  Calculator',
#  'CASIO FX-350MS 2nd Edition Scientific  Calculator',
#  'CASIO FX-82ES Plus 2nd Edition Scientific  Calculator',
#  'CASIO FX-991MS Scientific Scientific  Calculator',
#  'FLAIR 100 MS Scientific  Calculator',
#  'CASIO HL-4A Portable Basic  Calculator',
#  'CASIO MJ-12VCB-RD Desktop Basic  Calculator',
#  'CASIO MZ-12SA Desktop Basic  Calculator',
#  'CASIO MJ-12GST Desktop Basic  Calculator',
#  'CASIO MJ-120D Desktop Basic  Calculator',
#  'OREVA FX-750MS FX-750 MS Scientific  Calculator',
#  'BAMBALIO BL82MS 240 Functions & 2 Line Display 3 Years ...',
#  'CASIO DJ-220DPLUS Desktop Basic  Calculator',
#  'CASIO FX-100MS 2nd Edition Scientific  Calculator',
#  'CASIO MJ-120GST Desktop Basic  Calculator',
# ...

# %%
price=soup.select('._30jeq3')

# %%
price
# Out:
# [<div class="_30jeq3">₹418</div>,
#  <div class="_30jeq3">₹1,311</div>,
#  <div class="_30jeq3">₹523</div>,
#  <div class="_30jeq3">₹1,230</div>,
#  <div class="_30jeq3">₹479</div>,
#  <div class="_30jeq3">₹556</div>,
#  <div class="_30jeq3">₹708</div>,
#  <div class="_30jeq3">₹945</div>,
#  <div class="_30jeq3">₹492</div>,
#  <div class="_30jeq3">₹86</div>,
#  <div class="_30jeq3">₹310</div>,
#  <div class="_30jeq3">₹290</div>,
#  <div class="_30jeq3">₹423</div>,
#  <div class="_30jeq3">₹508</div>,
#  <div class="_30jeq3">₹449</div>,
#  <div class="_30jeq3">₹419</div>,
#  <div class="_30jeq3">₹892</div>,
#  <div class="_30jeq3">₹859</div>,
#  <div class="_30jeq3">₹565</div>,
#  <div class="_30jeq3">₹726</div>,
#  <div class="_30jeq3">₹306</div>,
#  <div class="_30jeq3">₹498</div>,
#  <div class="_30jeq3">₹451</div>,
#  <div class="_30jeq3">₹144</div>,
#  <div class="_30jeq3">₹281</div>,
#  <div class="_30jeq3">₹166</div>,
#  <div class="_30jeq3">₹270</div>,
# ...

# %% [markdown]
# # product price

# %%
products_price=[]

# %%
for items in price:
    products_price.append(item.text)

# %%
products_price
# Out:
# ['OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
#  'OREVA OR-750 Scientific  Calculator',
# ...

# %% [markdown]
# # products rating

# %%
rating=soup.select('._3LWZlK')

# %%
rating
# Out:
# [<div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
# ...

# %% [markdown]
# # product name

# %%
import pandas as pd

# %%
df=pd.DataFrame(products_title,columns=["products name"])

# %%
df
# Out:
#                                         products name
# 0           CASIO MJ-12D-BK Desktop Basic  Calculator
# 1      CASIO Classwiz FX-991EX Scientific  Calculator
# 2     CASIO FX-82MS Scientific Scientific  Calculator
# 3   CASIO FX-991ES Plus-2nd Edition Scientific Sci...
# 4    OREVA OR 240 MS OR 240 MS Scientific  Calculator
# 5   CASIO FX-350MS 2nd Edition Scientific  Calculator
# 6   CASIO FX-82ES Plus 2nd Edition Scientific  Cal...
# 7    CASIO FX-991MS Scientific Scientific  Calculator
# 8                 FLAIR 100 MS Scientific  Calculator
# 9              CASIO HL-4A Portable Basic  Calculator
# 10        CASIO MJ-12VCB-RD Desktop Basic  Calculator
# 11            CASIO MZ-12SA Desktop Basic  Calculator
# 12           CASIO MJ-12GST Desktop Basic  Calculator
# 13            CASIO MJ-120D Desktop Basic  Calculator
# 14    OREVA FX-750MS FX-750 MS Scientific  Calculator
# 15  BAMBALIO BL82MS 240 Functions & 2 Line Display...
# ...

# %% [markdown]
# # checking the data type

# %%
type(df.loc[0,'products name'])
# Out:
# str

# %%
import numpy as np

# %% [markdown]
# # saving the file

# %%
df.to_csv('calculator.csv')
